# %%
import matplotlib.pyplot as plt

# Each dataset = (x values, y values, label)
datasets = [
    (
        [13829, 25144, 37874, 51786, 81733],
        [0.2197555861, 0.4875278396, 0.5752019855, 0.6669292859, 0.7104572205],
        "Ages <30"
    ),
    
    (
        [13829, 25144, 37874, 51786, 81733],
        [0.2441969774, 0.44844098, 0.5903046945, 0.6845016027, 0.7578554562],
        "Ages 30-49"
    ),
    (
         [13829, 25144, 37874, 51786, 81733],
        [0.3382023284, 0.5096563793, 0.6179014627, 0.66612598, 0.7345062582],
        "Ages 50-64"
    ),
    (
         [13829, 25144, 37874, 51786, 81733],
        [0.422431123, 0.5615653834, 0.6386333633, 0.6956474723, 0.7449402322],
        "Ages 65-74"
    ),
    (
         [13829, 25144, 37874, 51786, 81733],
        [0.489362933, 0.626296532, 0.6956117653, 0.7155292936, 0.7750333403],
        "Ages >74"
    ),
]

plt.figure(figsize=(8, 6))

for x, y, label in datasets:
    plt.plot(x, y, marker="o", label=label)

plt.xlabel("After-Tax Income")
plt.ylabel("Disposable Income / Post-Tax Income")
plt.title("Post-Tax Income vs Disposable Income Ratio")

plt.legend()
plt.grid(True)

plt.show()
